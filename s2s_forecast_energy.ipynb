# %%
# System libs for ECMWF ecCodes
# !apt-get update -y
# !apt-get install -y libeccodes0 libeccodes-data

# Python packages
# !pip install -q eccodes cfgrib xarray
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,799 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,278 kB]
# ...

# %%
import xarray as xr
ds = xr.open_dataset(
    "ecmwf_s2s.grib",
    engine="cfgrib",)
# Out:
# /usr/local/lib/python3.12/dist-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode the variable 'step' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(

# %%
ds
# Out:
# <xarray.Dataset> Size: 278MB
# Dimensions:            (time: 26, step: 46, latitude: 121, longitude: 240)
# Coordinates:
#     number             int64 8B ...
#   * time               (time) datetime64[ns] 208B 2025-08-01 ... 2025-08-26
#   * step               (step) timedelta64[ns] 368B 1 days 2 days ... 46 days
#     heightAboveGround  float64 8B ...
#   * latitude           (latitude) float64 968B 90.0 88.5 87.0 ... -88.5 -90.0
#   * longitude          (longitude) float64 2kB 0.0 1.5 3.0 ... 355.5 357.0 358.5
#     valid_time         (time, step) datetime64[ns] 10kB ...
#     entireAtmosphere   float64 8B ...
# Data variables:
#     t2m                (time, step, latitude, longitude) float32 139MB ...
#     tcc                (time, step, latitude, longitude) float32 139MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
# ...
